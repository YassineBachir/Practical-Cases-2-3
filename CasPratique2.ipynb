# %% [markdown]
# # Yassine Mouhamed Bachir NDIAYE
# # Rokhaya FALL
# # Ndeye Ndiaye

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Question 1:

# %%
Notes=pd.read_excel("examens.xlsx")
Notes
# Out:
#         Nom       Prénom  Physique 1  Physique 2  TP Physique   Maths 1  \
# 0    DIALLO     Ibrahima      18.100      14.300           13    13.600
# 1        BA   Souleymane      19.700      17.600           16    16.000
# 2      BEYE      Alioune       4.750       4.300           10     8.602
# 3     BIAYE      Babacar      15.200      10.600           16    15.100
# 4     BALDE      Mamadou       4.700       7.100           15    13.150
# 5    CAMARA  Khadidiatou      13.700      11.100           10    10.252
# 6     CISSE          Awa      16.500      15.600           13    16.450
# 7     CISSE      Ousmane      15.100       6.700           10    12.800
# 8    DIAGNE        Marie      17.250      14.700           15    16.900
# 9      DIAW         Omar       2.900       8.600           15    10.000
# 10   DIATTA      Justine       6.798      10.800           16     3.700
# 11   DIALLO       Moussa       0.000       0.000            0     1.900
# ...

# %% [markdown]
# # Question 2:

# %%
#Calcul de la moyenne
Tableau=Notes[Notes.columns[2:]].values
Tableau
# Out:
# array([[18.1  , 14.3  , 13.   , 13.6  , 15.8  , 14.   , 11.5  , 16.   ,
#         16.   , 15.2  , 14.4  , 10.   , 17.   , 10.4  , 10.   ],
#        [19.7  , 17.6  , 16.   , 16.   , 19.   , 16.6  , 16.8  ,  0.   ,
#         20.   , 20.   , 16.   , 12.   , 16.   , 15.6  , 18.   ],
#        [ 4.75 ,  4.3  , 10.   ,  8.602, 11.4  ,  5.4  ,  8.4  ,  6.   ,
#          2.8  ,  6.1  ,  8.4  ,  7.   , 11.   , 15.6  , 11.   ],
#        [15.2  , 10.6  , 16.   , 15.1  , 15.   , 18.6  ,  8.2  ,  8.   ,
#         15.8  , 14.8  , 14.4  , 11.   , 13.   ,  9.4  , 14.   ],
#        [ 4.7  ,  7.1  , 15.   , 13.15 , 16.   , 10.6  , 11.   , 16.   ,
#          7.2  , 14.9  , 13.4  ,  8.   , 12.   , 14.8  , 15.   ],
#        [13.7  , 11.1  , 10.   , 10.252,  9.752,  9.4  , 12.9  , 20.   ,
#          8.8  ,  7.6  , 11.6  ,  7.   , 15.   ,  8.2  ,  7.   ],
#        [16.5  , 15.6  , 13.   , 16.45 , 14.6  , 15.8  , 10.3  ,  6.   ,
#         17.   , 16.1  , 14.8  , 10.   , 12.   , 13.6  , 10.   ],
# ...

# %%
NotesPhysique=Tableau[:,0:3]
NotesPhysique
# Out:
# array([[18.1  , 14.3  , 13.   ],
#        [19.7  , 17.6  , 16.   ],
#        [ 4.75 ,  4.3  , 10.   ],
#        [15.2  , 10.6  , 16.   ],
#        [ 4.7  ,  7.1  , 15.   ],
#        [13.7  , 11.1  , 10.   ],
#        [16.5  , 15.6  , 13.   ],
#        [15.1  ,  6.7  , 10.   ],
#        [17.25 , 14.7  , 15.   ],
#        [ 2.9  ,  8.6  , 15.   ],
#        [ 6.798, 10.8  , 16.   ],
#        [ 0.   ,  0.   ,  0.   ],
#        [ 8.65 ,  9.352, 15.   ],
#        [ 8.   , 10.8  , 13.   ],
#        [11.25 , 11.68 , 15.   ],
#        [ 9.8  ,  9.   , 13.   ],
#        [12.7  , 17.   , 16.   ],
#        [13.55 , 16.3  , 13.   ],
#        [13.15 , 17.8  , 10.   ],
#        [ 0.   ,  0.   ,  0.   ],
#        [19.4  , 20.   , 13.   ],
#        [ 2.4  ,  5.6  ,  0.   ],
#        [16.9  , 12.8  , 16.   ],
#        [ 3.4  ,  3.3  , 16.   ],
#        [ 7.81 , 11.   , 13.   ],
#        [ 0.   ,  0.   ,  0.   ],
#        [15.3  , 14.   , 15.   ],
#        [ 1.75 ,  4.9  , 18.   ],
# ...

# %%
Coef1=[2.5,2.5,1]
#M=[]
for j in range(len(NotesPhysique)):
    for i in range(0,3):
        NotesPhysique[j,i]=NotesPhysique[j,i]*Coef1[i]
        #M.append(M1)
NotesPhysique
moyen_Phy=np.sum(NotesPhysique,axis=1)/6

moyen_Phy
# Out:
# array([15.66666667, 18.20833333,  5.4375    , 13.41666667,  7.41666667,
#        12.        , 15.54166667, 10.75      , 15.8125    ,  7.29166667,
#         9.99916667,  0.        , 10.00083333, 10.        , 12.05416667,
#        10.        , 15.04166667, 14.60416667, 14.5625    ,  0.        ,
#        18.58333333,  3.33333333, 15.04166667,  5.45833333, 10.00416667,
#         0.        , 14.70833333,  5.77083333, 18.0625    ,  0.        ,
#         7.66666667, 11.58333333,  0.        ,  0.        , 15.875     ,
#        15.91666667, 11.70833333, 10.41666667,  0.        ,  0.        ,
#        10.66666667, 13.08333333, 13.        , 15.83333333])

# %%
#Validation 
V1=[]
credit_Phy=[]
for i in range(len(moyen_Phy)):
    if moyen_Phy[i] >=10:
        V1.append("V")
        credit_Phy.append(12)
        

    else:
        V1.append("NV")
        credit_Phy.append(0)
V1
# Out:
# ['V',
#  'V',
#  'NV',
#  'V',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'NV',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'V',
#  'NV',
#  'V',
#  'NV',
#  'V',
#  'NV',
#  'V',
#  'NV',
#  'V',
#  'NV',
#  'NV',
#  'V',
#  'NV',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'V']

# %% [markdown]
# # Moyenne Maths

# %%
NotesMaths=Tableau[:,3:5]
NotesMaths
# Out:
# array([[13.6  , 15.8  ],
#        [16.   , 19.   ],
#        [ 8.602, 11.4  ],
#        [15.1  , 15.   ],
#        [13.15 , 16.   ],
#        [10.252,  9.752],
#        [16.45 , 14.6  ],
#        [12.8  , 13.4  ],
#        [16.9  , 16.9  ],
#        [10.   , 16.4  ],
#        [ 3.7  ,  8.6  ],
#        [ 1.9  ,  0.   ],
#        [ 8.05 , 11.94 ],
#        [ 6.7  ,  7.8  ],
#        [15.85 , 17.3  ],
#        [ 9.4  , 17.   ],
#        [19.   , 18.1  ],
#        [17.5  , 17.2  ],
#        [13.9  , 15.8  ],
#        [ 0.   ,  0.   ],
#        [18.1  , 18.4  ],
#        [ 4.9  ,  5.2  ],
#        [18.55 , 17.5  ],
#        [ 8.8  , 13.7  ],
#        [ 9.4  , 11.2  ],
#        [ 5.95 ,  4.2  ],
#        [13.68 , 14.6  ],
#        [ 6.   , 10.6  ],
#        [15.55 , 15.6  ],
#        [ 1.9  ,  0.   ],
#        [13.45 , 13.1  ],
#        [10.45 ,  9.55 ],
#        [ 0.   ,  0.   ],
#        [ 1.9  ,  0.   ],
#        [13.6  , 11.5  ],
#        [ 7.45 , 14.1  ],
#        [ 9.55 , 14.2  ],
# ...

# %%
#MATHS

Coef2=[2.5,2.5]
for j in range(len(NotesMaths)):
    for i in range(2):
        NotesMaths[j,i]=NotesMaths[j,i]*Coef2[i]
        #M.append(M1)
NotesMaths
moyen_Maths=np.sum(NotesMaths, axis=1)/5
moyen_Maths
# Out:
# array([14.7  , 17.5  , 10.001, 15.05 , 14.575, 10.002, 15.525, 13.1  ,
#        16.9  , 13.2  ,  6.15 ,  0.95 ,  9.995,  7.25 , 16.575, 13.2  ,
#        18.55 , 17.35 , 14.85 ,  0.   , 18.25 ,  5.05 , 18.025, 11.25 ,
#        10.3  ,  5.075, 14.14 ,  8.3  , 15.575,  0.95 , 13.275, 10.   ,
#         0.   ,  0.95 , 12.55 , 10.775, 11.875, 10.8  ,  0.   ,  4.   ,
#        15.   , 10.   , 12.375, 15.975])

# %%
V2=[]
credit_Math=[]
for i in range(len(moyen_Maths)):
    if moyen_Maths[i] >=10:
        V2.append("V")
        credit_Math.append(10)
    else:
        V2.append("NV")
        credit_Math.append(0)
V2
# Out:
# ['V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'NV',
#  'NV',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'V',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'V',
#  'NV',
#  'V',
#  'NV',
#  'V',
#  'V',
#  'NV',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'V']

# %% [markdown]
# # Moyenne Chimie

# %%
#CHIMIE
NotesChimie=Tableau[:,5:8]
NotesChimie
# Out:
# array([[14.  , 11.5 , 16.  ],
#        [16.6 , 16.8 ,  0.  ],
#        [ 5.4 ,  8.4 ,  6.  ],
#        [18.6 ,  8.2 ,  8.  ],
#        [10.6 , 11.  , 16.  ],
#        [ 9.4 , 12.9 , 20.  ],
#        [15.8 , 10.3 ,  6.  ],
#        [12.6 ,  8.7 , 19.  ],
#        [13.  , 16.1 , 14.  ],
#        [14.4 , 11.3 , 12.  ],
#        [11.  ,  5.4 , 19.  ],
#        [ 0.  ,  0.  ,  0.  ],
#        [ 9.8 ,  8.  , 19.  ],
#        [11.2 ,  9.1 ,  9.25],
#        [15.2 , 10.  , 14.  ],
#        [11.8 , 11.8 ,  0.  ],
#        [17.6 , 17.6 , 19.  ],
#        [12.8 , 12.7 , 14.  ],
#        [15.8 , 11.3 , 14.  ],
#        [ 0.  ,  0.  ,  0.  ],
#        [16.4 , 16.7 , 18.  ],
#        [ 4.4 ,  1.6 ,  0.  ],
#        [18.2 , 16.1 , 20.  ],
#        [10.8 ,  6.6 , 19.  ],
#        [ 9.6 , 10.3 , 19.  ],
#        [11.2 ,  5.4 ,  0.  ],
#        [14.8 ,  6.2 , 19.  ],
#        [ 9.4 ,  4.9 , 16.  ],
#        [15.8 , 13.9 , 20.  ],
#        [ 0.  ,  0.  ,  0.  ],
#        [14.2 ,  3.9 ,  0.  ],
# ...

# %%
Coef3=[2.5,2.5,1]
for j in range(len(NotesChimie)):
    for i in range(3):
        NotesChimie[j,i]=NotesChimie[j,i]*Coef3[i]
        #M.append(M1)
NotesChimie
moyen_Chimie=np.sum(NotesChimie, axis=1)/6
moyen_Chimie
# Out:
# array([13.29166667, 13.91666667,  6.75      , 12.5       , 11.66666667,
#        12.625     , 11.875     , 12.04166667, 14.45833333, 12.70833333,
#        10.        ,  0.        , 10.58333333, 10.        , 12.83333333,
#         9.83333333, 17.83333333, 12.95833333, 13.625     ,  0.        ,
#        16.79166667,  2.5       , 17.625     , 10.41666667, 11.45833333,
#         6.91666667, 11.91666667,  8.625     , 15.70833333,  0.        ,
#         7.54166667, 11.25      ,  0.        ,  0.        , 12.875     ,
#        12.41666667, 12.95833333, 11.16666667,  0.        ,  2.83333333,
#         8.58333333, 15.91666667, 15.75      , 11.08333333])

# %%
V3=[]
credit_Chimie=[]
for i in range(len(moyen_Chimie)):
    if moyen_Chimie[i] >=10:
        V3.append("V")
        credit_Chimie.append(12)
    else:
        V3.append("NV")
        credit_Chimie.append(0)
V3
# Out:
# ['V',
#  'V',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'V',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'V',
#  'NV',
#  'V',
#  'NV',
#  'NV',
#  'V',
#  'NV',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'NV',
#  'NV',
#  'V',
#  'V',
#  'V']

# %% [markdown]
# # Moyenne Infos

# %%
NotesInfos=Tableau[:,8:10]
NotesInfos
# Out:
# array([[16. , 15.2],
#        [20. , 20. ],
#        [ 2.8,  6.1],
#        [15.8, 14.8],
#        [ 7.2, 14.9],
#        [ 8.8,  7.6],
#        [17. , 16.1],
#        [ 9.6, 10.4],
#        [19. , 17.4],
#        [ 8.6, 18.6],
#        [ 3.6,  6. ],
#        [ 0. ,  0. ],
#        [14.8, 12.1],
#        [11.2, 12.6],
#        [16.4, 12.1],
#        [15.2, 14. ],
#        [16.4, 20. ],
#        [10.2, 17.9],
#        [12.4, 17. ],
#        [ 0. ,  0. ],
#        [18.2, 18.6],
#        [ 2.8,  4.4],
#        [20. , 19.1],
#        [11.6, 10.2],
#        [11.8, 14.5],
#        [ 2. ,  2.4],
#        [17.4, 12.6],
#        [ 6.4,  5.6],
#        [20. , 19.7],
#        [ 0. ,  0. ],
#        [ 3.6,  3.9],
#        [10. , 15. ],
#        [ 0. ,  0. ],
#        [ 0. ,  0. ],
#        [14.4, 15.7],
#        [16. , 17.4],
#        [12.8, 11.8],
#        [15.8, 14.1],
#        [ 0. ,  0. ],
#        [ 2. ,  3.6],
#        [12. ,  8. ],
#        [14. , 12. ],
#        [12.2, 13.6],
# ...

# %%
Coef4=[2.5,2.5]
for j in range(len(NotesInfos)):
    for i in range(2):
        NotesInfos[j,i]=NotesInfos[j,i]*Coef4[i]
        #M.append(M1)

moyenne_Infos=np.sum(NotesInfos, axis=1)/5
moyenne_Infos
# Out:
# array([15.6 , 20.  ,  4.45, 15.3 , 11.05,  8.2 , 16.55, 10.  , 18.2 ,
#        13.6 ,  4.8 ,  0.  , 13.45, 11.9 , 14.25, 14.6 , 18.2 , 14.05,
#        14.7 ,  0.  , 18.4 ,  3.6 , 19.55, 10.9 , 13.15,  2.2 , 15.  ,
#         6.  , 19.85,  0.  ,  3.75, 12.5 ,  0.  ,  0.  , 15.05, 16.7 ,
#        12.3 , 14.95,  0.  ,  2.8 , 10.  , 13.  , 12.9 , 16.55])

# %%
V4=[]
credit_Info=[]
for i in range(len(moyenne_Infos)):
    if moyenne_Infos[i] >=10:
        V4.append("V")
        credit_Info.append(10)
    else:
        V4.append("NV")
        credit_Info.append(0)
V4
# Out:
# ['V',
#  'V',
#  'NV',
#  'V',
#  'V',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'V',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'V',
#  'NV',
#  'V',
#  'NV',
#  'NV',
#  'V',
#  'NV',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'V']

# %% [markdown]
# # Moyenne Outils_Base

# %%
#OUTILS de Base
notes_Ob=Tableau[:,10:13]
notes_Ob
# Out:
# array([[14.4 , 10.  , 17.  ],
#        [16.  , 12.  , 16.  ],
#        [ 8.4 ,  7.  , 11.  ],
#        [14.4 , 11.  , 13.  ],
#        [13.4 ,  8.  , 12.  ],
#        [11.6 ,  7.  , 15.  ],
#        [14.8 , 10.  , 12.  ],
#        [14.8 ,  8.  , 14.  ],
#        [ 9.  ,  7.  , 17.  ],
#        [13.56, 10.  , 15.  ],
#        [ 6.6 , 12.  , 14.  ],
#        [ 0.  ,  0.  ,  0.  ],
#        [11.6 ,  7.  , 17.  ],
#        [16.  , 10.  , 16.  ],
#        [15.  , 11.  , 18.  ],
#        [15.4 , 10.  , 15.  ],
#        [15.  , 10.  , 14.  ],
#        [14.4 , 13.  , 13.  ],
#        [13.4 ,  7.  , 14.  ],
#        [ 0.  ,  0.  ,  0.  ],
#        [14.44, 14.  , 17.  ],
#        [ 7.  ,  0.  ,  0.  ],
#        [16.2 , 13.  , 18.  ],
#        [ 7.2 , 11.  , 16.  ],
#        [ 7.8 , 10.  , 17.  ],
#        [ 0.  ,  0.  ,  0.  ],
#        [14.8 ,  9.  , 13.  ],
#        [11.6 , 10.  , 16.  ],
#        [14.24, 10.  , 15.  ],
#        [ 0.  ,  0.  ,  0.  ],
#        [16.  , 10.  , 12.  ],
# ...

# %%
Coef5=[1.5,1.5,1]
for j in range(len(notes_Ob)):
    for i in range(3):
        notes_Ob[j,i]=notes_Ob[j,i]*Coef5[i]
moyenne_Ob=np.sum(notes_Ob, axis=1)/4
moyenne_Ob
# Out:
# array([13.4  , 14.5  ,  8.525, 12.775, 11.025, 10.725, 12.3  , 12.05 ,
#        10.25 , 12.585, 10.475,  0.   , 11.225, 13.75 , 14.25 , 13.275,
#        12.875, 13.525, 11.15 ,  0.   , 14.915,  2.625, 15.45 , 10.825,
#        10.925,  0.   , 12.175, 12.1  , 12.84 ,  0.   , 12.75 , 13.075,
#         0.   ,  0.   , 10.35 , 12.95 , 13.65 , 11.775,  0.   ,  0.   ,
#         5.5  , 11.125, 11.   , 12.375])

# %%
V5=[]
credit_Ob=[]
for i in range(len(moyenne_Ob)):
    if moyenne_Ob[i] >=10:
        V5.append("V")
        credit_Ob.append(8)

    else:
        V5.append("NV")
        credit_Ob.append(0)
V5
# Out:
# ['V',
#  'V',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'V',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'V',
#  'V',
#  'NV',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'NV',
#  'NV',
#  'V',
#  'V',
#  'V']

# %% [markdown]
# # Moyenne Graphique

# %%
#GR
notes_GR=Tableau[:,13:]
notes_GR
# Out:
# array([[10.4, 10. ],
#        [15.6, 18. ],
#        [15.6, 11. ],
#        [ 9.4, 14. ],
#        [14.8, 15. ],
#        [ 8.2,  7. ],
#        [13.6, 10. ],
#        [ 4.8, 12. ],
#        [12.2, 17. ],
#        [13.4, 15. ],
#        [10.8, 14. ],
#        [ 0. ,  0. ],
#        [13. , 15. ],
#        [11. , 12. ],
#        [11.6, 10. ],
#        [11.4, 13. ],
#        [14. , 13. ],
#        [13.6, 16. ],
#        [12.6, 14. ],
#        [ 0. ,  0. ],
#        [16.2, 17. ],
#        [ 0. ,  0. ],
#        [14.4, 14. ],
#        [11. , 12. ],
#        [17.4, 17. ],
#        [ 5.4,  0. ],
#        [13.8, 13. ],
#        [14. , 12. ],
#        [12.2, 17. ],
#        [ 0. ,  0. ],
#        [14. ,  6. ],
#        [12.2, 16. ],
#        [ 0. ,  0. ],
#        [ 0. ,  0. ],
#        [13.6,  9. ],
#        [13.4,  7. ],
#        [11.4, 10. ],
#        [12.6, 10. ],
#        [ 0. ,  0. ],
#        [ 0. ,  0. ],
#        [ 9. ,  8. ],
#        [13. , 12. ],
#        [15.4, 14. ],
# ...

# %%
Coef6=[2,2]
for j in range(len(notes_GR)):
    for i in range(2):
        notes_GR[j,i]=notes_GR[j,i]*Coef6[i]
moyenne_GR=np.sum(notes_GR, axis=1)/4
moyenne_GR
# Out:
# array([10.2, 16.8, 13.3, 11.7, 14.9,  7.6, 11.8,  8.4, 14.6, 14.2, 12.4,
#         0. , 14. , 11.5, 10.8, 12.2, 13.5, 14.8, 13.3,  0. , 16.6,  0. ,
#        14.2, 11.5, 17.2,  2.7, 13.4, 13. , 14.6,  0. , 10. , 14.1,  0. ,
#         0. , 11.3, 10.2, 10.7, 11.3,  0. ,  0. ,  8.5, 12.5, 14.7, 12.8])

# %%
V6=[]
credit_G=[]
for i in range(len(moyenne_GR)):
    if moyenne_GR[i] >=10:
        V6.append("V")
        credit_G.append(8)
    else:
        V6.append("NV")
        credit_G.append(0)
V6
# Out:
# ['V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'V',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'V',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'V',
#  'V',
#  'NV',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'NV',
#  'NV',
#  'V',
#  'V',
#  'V']

# %%
Notes.insert(5,"Moy_Phy",moyen_Phy,allow_duplicates=False)
Notes.insert(6,"Decision",V1,allow_duplicates=False)

Notes.insert(9,"Moy_Math",moyen_Maths,allow_duplicates=False)
Notes.insert(10,"DecisionM",V2,allow_duplicates=False)

Notes.insert(14,"Moy_Chimie",moyen_Chimie,allow_duplicates=False)
Notes.insert(15,"DecisionC",V3,allow_duplicates=False)

Notes.insert(18,"Moy_Infos",moyenne_Infos,allow_duplicates=False)
Notes.insert(19,"DecisionI",V4,allow_duplicates=False)

Notes.insert(23,"Moy_Ob",moyenne_Ob,allow_duplicates=False)
Notes.insert(24,"DecisionB",V5,allow_duplicates=False)

Notes.insert(27,"Moy_GR",moyenne_GR,allow_duplicates=False)
Notes.insert(28,"DecisionG",V6,allow_duplicates=False)
Notes
# Out:
#         Nom       Prénom  Physique 1  Physique 2  TP Physique    Moy_Phy  \
# 0    DIALLO     Ibrahima      18.100      14.300           13  15.666667
# 1        BA   Souleymane      19.700      17.600           16  18.208333
# 2      BEYE      Alioune       4.750       4.300           10   5.437500
# 3     BIAYE      Babacar      15.200      10.600           16  13.416667
# 4     BALDE      Mamadou       4.700       7.100           15   7.416667
# 5    CAMARA  Khadidiatou      13.700      11.100           10  12.000000
# 6     CISSE          Awa      16.500      15.600           13  15.541667
# 7     CISSE      Ousmane      15.100       6.700           10  10.750000
# 8    DIAGNE        Marie      17.250      14.700           15  15.812500
# 9      DIAW         Omar       2.900       8.600           15   7.291667
# 10   DIATTA      Justine       6.798      10.800           16   9.999167
# 11   DIALLO       Moussa       0.000       0.000            0   0.000000
# ...

# %% [markdown]
# # Trie des noms et prenoms

# %%
Nom_Prenom=Notes.sort_values(by=["Nom","Prénom"],ascending=[True,True])
Nom_Prenom
# Out:
#         Nom       Prénom  Physique 1  Physique 2  TP Physique    Moy_Phy  \
# 1        BA   Souleymane      19.700      17.600           16  18.208333
# 4     BALDE      Mamadou       4.700       7.100           15   7.416667
# 2      BEYE      Alioune       4.750       4.300           10   5.437500
# 3     BIAYE      Babacar      15.200      10.600           16  13.416667
# 5    CAMARA  Khadidiatou      13.700      11.100           10  12.000000
# 6     CISSE          Awa      16.500      15.600           13  15.541667
# 7     CISSE      Ousmane      15.100       6.700           10  10.750000
# 8    DIAGNE        Marie      17.250      14.700           15  15.812500
# 0    DIALLO     Ibrahima      18.100      14.300           13  15.666667
# 11   DIALLO       Moussa       0.000       0.000            0   0.000000
# 16     DIAO      Mariama      12.700      17.000           16  15.041667
# 10   DIATTA      Justine       6.798      10.800           16   9.999167
# ...

# %% [markdown]
# # Q5:Enregistrement dans le fichier Excel

# %%
Resultats=pd.ExcelWriter("Deliberation.xlsx", engine="xlsxwriter")
Notes.to_excel(Resultats,"Resultats_Annuelle", index=False)
Resultats.save()

# %% [markdown]
# # Question 6:

# %%
#Calcul des moyennes

notes= Notes.iloc[:,2:]
notes
# Out:
#     Physique 1  Physique 2  TP Physique    Moy_Phy Decision   Maths 1  \
# 0       18.100      14.300           13  15.666667        V    13.600
# 1       19.700      17.600           16  18.208333        V    16.000
# 2        4.750       4.300           10   5.437500       NV     8.602
# 3       15.200      10.600           16  13.416667        V    15.100
# 4        4.700       7.100           15   7.416667       NV    13.150
# 5       13.700      11.100           10  12.000000        V    10.252
# 6       16.500      15.600           13  15.541667        V    16.450
# 7       15.100       6.700           10  10.750000        V    12.800
# 8       17.250      14.700           15  15.812500        V    16.900
# 9        2.900       8.600           15   7.291667       NV    10.000
# 10       6.798      10.800           16   9.999167       NV     3.700
# 11       0.000       0.000            0   0.000000       NV     1.900
# ...

# %% [markdown]
# # Question 7:

# %%
#Nombre d'etudiants ayant validé 

N=[]
S_P=0

for i in range(len(V1)):
    if V1[i]=="V":
        S_P=S_P+1

#print("Il y'a ",S_P,"étudiants qui ont validé la physique")

#print("Il y'a ",S_P,"étudiants qui ont validé la physique")

# %%
S_M=0

for i in range(len(V2)):
    if V2[i]=="V":
        S_M=S_M+1
#print("Il y'a ",S_M,"étudiants qui ont validé les maths")

# %%
S_C=0

for i in range(len(V3)):
    if V3[i]=="V":
        S_C=S_C+1
#print("Il y'a ",S_C,"étudiants qui ont validé la chimie")

# %%
S_I=0

for i in range(len(V4)):
    if V4[i]=="V":
        S_I=S_I+1
#print("Il y'a ",S_I,"étudiants qui ont validé l'informatique")

# %%
S_OB=0

for i in range(len(V5)):
    if V5[i]=="V":
        S_OB=S_OB+1
#rint("Il y'a ",S_OB,"étudiants qui ont validé les outils de base")

# %%
N=[]
S_G=0

for i in range(len(V6)):
    if V6[i]=="V":
        S_G=S_G+1
#print("Il y'a ",S_G,"étudiants qui ont validé le Graphique")

# %% [markdown]
# # Nombre d etudiants ayant validé chaque UE

# %%
phy = notes.loc[notes.loc[:, "Decision"] == "V"]
mat = notes.loc[notes.loc[:, "DecisionM"] == "V"]
chi =notes.loc[notes.loc[:, "DecisionC"] == "V"]
inf = notes.loc[notes.loc[:, "DecisionI"] == "V"]
base = notes.loc[notes.loc[:, "DecisionB"] == "V"]
gr = notes.loc[notes.loc[:, "DecisionG"] == "V"]
Nombre_Valide = [len(phy), len(mat), len(chi), len(inf), len(base), len(gr)]
Nombre_Valide
# Out:
# [28, 31, 30, 30, 33, 32]

# %%
UE=["Physique","Mathématique", "Chimie","Informatique","OutilsBases","Graphique"]
UE
# Out:
# ['Physique',
#  'Mathématique',
#  'Chimie',
#  'Informatique',
#  'OutilsBases',
#  'Graphique']

# %% [markdown]
# # Question 8:

# %%
import matplotlib.pyplot as plt
fig1, axe1= plt.subplots(figsize=(12,10))
x=UE
y=Nombre_Valide
plt.grid()
plt.plot(x,y)
plt.show()

# %%
MoyG=(moyen_Phy+moyen_Maths+moyen_Chimie+moyenne_Infos+moyenne_Ob+moyenne_GR)/(6)
MoyG
# Out:
# array([13.80972222, 16.82083333,  8.07725   , 13.45694444, 11.77222222,
#        10.192     , 13.93194444, 11.05694444, 15.03680556, 12.26416667,
#         8.97069444,  0.15833333, 11.54236111, 10.73333333, 13.46041667,
#        12.18472222, 16.        , 14.54791667, 13.69791667,  0.        ,
#        17.25666667,  2.85138889, 16.64861111, 10.05833333, 12.17291667,
#         2.81527778, 13.55666667,  8.96597222, 16.10597222,  0.15833333,
#         9.16388889, 12.08472222,  0.        ,  0.15833333, 13.        ,
#        13.15972222, 12.19861111, 11.73472222,  0.        ,  1.60555556,
#         9.70833333, 12.60416667, 13.2875    , 14.10277778])

# %%
totalCredit=[]
for i in range(len(MoyG)):
    totalCredit.append(credit_Phy[i]+credit_Math[i]+credit_Chimie[i]+credit_Info[i]+credit_Ob[i]+credit_G[i])
totalCredit
# Out:
# [60,
#  60,
#  18,
#  60,
#  48,
#  42,
#  60,
#  52,
#  60,
#  48,
#  28,
#  0,
#  50,
#  50,
#  60,
#  48,
#  60,
#  60,
#  60,
#  0,
#  60,
#  0,
#  60,
#  48,
#  60,
#  0,
#  60,
#  16,
#  60,
#  0,
#  26,
#  60,
#  0,
#  0,
#  60,
#  60,
#  60,
#  60,
#  0,
#  0,
#  32,
#  60,
#  60,
#  60]

# %% [markdown]
# # Insertion dans le dataframe

# %%
Notes.insert(29,"Moy_Annuelle",MoyG,allow_duplicates=False)
Notes.insert(30,"CreditsTotal",totalCredit,allow_duplicates=False)
Notes
# Out:
#         Nom       Prénom  Physique 1  Physique 2  TP Physique    Moy_Phy  \
# 0    DIALLO     Ibrahima      18.100      14.300           13  15.666667
# 1        BA   Souleymane      19.700      17.600           16  18.208333
# 2      BEYE      Alioune       4.750       4.300           10   5.437500
# 3     BIAYE      Babacar      15.200      10.600           16  13.416667
# 4     BALDE      Mamadou       4.700       7.100           15   7.416667
# 5    CAMARA  Khadidiatou      13.700      11.100           10  12.000000
# 6     CISSE          Awa      16.500      15.600           13  15.541667
# 7     CISSE      Ousmane      15.100       6.700           10  10.750000
# 8    DIAGNE        Marie      17.250      14.700           15  15.812500
# 9      DIAW         Omar       2.900       8.600           15   7.291667
# 10   DIATTA      Justine       6.798      10.800           16   9.999167
# 11   DIALLO       Moussa       0.000       0.000            0   0.000000
# ...

# %% [markdown]
# # Detremination du/de la major(e) de la classe

# %%
print("Le/La major(e) est:",Notes.Prénom[np.where(Notes.Moy_Annuelle.values==Notes.Moy_Annuelle.max())[0][0]],
     Notes.Nom[np.where(Notes.Moy_Annuelle.values==Notes.Moy_Annuelle.max())[0][0]])
print("Moyenne:",Notes.Moy_Annuelle.max())
# Out:
# Le/La major(e) est: Maimouna KEBE
# Moyenne: 17.256666666666664

# %% [markdown]
# # Insertation de la courde dans excel

# %%
import xlwings as resultats
Resultats=resultats.Book("Deliberation.xlsx")
Resultats.sheets.add("Resutats finals")
R=Resultats.sheets["Resutats finals"]
axe1=axe1.get_figure()
R.pictures.add(axe1,name="Resultas_Examen",update=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2392/433364717.py in <module>
#       1 import xlwings as resultats
#       2 Resultats=resultats.Book("Deliberation.xlsx")
# ----> 3 Resultats.sheets.add("Resutats finals")
#       4 R=Resultats.sheets["Resutats finals"]
#       5 axe1=axe1.get_figure()
#
# ~\anaconda3\lib\site-packages\xlwings\main.py in add(self, name, before, after)
#    4336         if name is not None:
#    4337             if name.lower() in (s.name.lower() for s in self):
# -> 4338                 raise ValueError("Sheet named '%s' already present in workbook" % name)
#    4339         if before is not None and not isinstance(before, Sheet):
#    4340             before = self(before)
#
# ValueError: Sheet named 'Resutats finals' already present in workbook

# %%
#Insertion: ceci nous permettra d'eviter les erreurs d'insertion
#if "Colonne exixtant" in Datataframe.columns:
    #del DataFrame["Colonne exixtant"]
#else 
#On insere directement
